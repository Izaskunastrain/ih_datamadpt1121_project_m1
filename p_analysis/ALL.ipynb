# %%
# Import libraries
import pandas as pd
import requests
import re
from shapely.geometry import Point
import geopandas as gpd   # conda install -c conda-forge geopandas

# %%
# Acquistion of data

# %%
#Bicimad

# %%
df_bicimad_original = pd.read_csv('../data/bicimad_stations.csv')
df_bicimad = df_bicimad_original [['name', 'address', 'geometry_coordinates']]

def lat (x):
    b= x.split(',')
    c= b[0].replace('[','')
    d= float(c)
    return d
    
def long (x):
    b= x.split(',')
    c= b[1].replace(']','')
    d= float(c)
    return d

# %%
df_bicimad['Longitude.bicimad'] = df_bicimad.apply(lambda x: lat(x['geometry_coordinates']),axis=1)
df_bicimad['Latitude.bicimad'] = df_bicimad.apply(lambda x: long(x['geometry_coordinates']),axis=1)
df_bicimad
# Out:
# /Users/Izaskun/miniconda3/envs/bicimad/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/Izaskun/miniconda3/envs/bicimad/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  \
# 0                                  Puerta del Sol nº 1
# 1                                  Puerta del Sol nº 1
# 2                               Calle Miguel Moya nº 1
# 3             Plaza del Conde del Valle de Súchil nº 3
# 4                          Calle Manuela Malasaña nº 5
# ..                                                 ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...
# 260  Avenida de la Complutense (Metro Ciudad Univer...
# 261          Calle José Antonio Novais frente al nº 12
# 262                          Avenida Complutense nº 23
# 263                                Calle Zurbano nº 90
#
#                         geometry_coordinates  Latitude  Longitude  \
# 0                   [-3.7018341, 40.4172137] -3.701834  40.417214
# 1    [-3.701602938060457, 40.41731271011562] -3.701603  40.417313
# 2                   [-3.7058415, 40.4205886] -3.705842  40.420589
# 3                   [-3.7069171, 40.4302937] -3.706917  40.430294
# 4                   [-3.7025875, 40.4285524] -3.702587  40.428552
# ..                                       ...       ...        ...
# 259                     [-3.72699, 40.44375] -3.726990  40.443750
# 260                     [-3.72693, 40.44342] -3.726930  40.443420
# 261                 [-3.7272945, 40.4483322] -3.727295  40.448332
# 262                     [-3.72937, 40.45109] -3.729370  40.451090
# 263                     [-3.69281, 40.43837] -3.692810  40.438370
#
#      Latitude.bicimad  Longitude.bicimad
# 0           40.417214          -3.701834
# 1           40.417313          -3.701603
# 2           40.420589          -3.705842
# 3           40.430294          -3.706917
# 4           40.428552          -3.702587
# ..                ...                ...
# 259         40.443750          -3.726990
# 260         40.443420          -3.726930
# 261         40.448332          -3.727295
# 262         40.451090          -3.729370
# 263         40.438370          -3.692810
#
# [264 rows x 7 columns]

# %%
df_bicimad_final= df_bicimad[['name', 'address', 'Latitude.bicimad', 'Longitude.bicimad']]

# %%
df_bicimad_final
# Out:
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  Latitude.bicimad  \
# 0                                  Puerta del Sol nº 1         40.417214
# 1                                  Puerta del Sol nº 1         40.417313
# 2                               Calle Miguel Moya nº 1         40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4                          Calle Manuela Malasaña nº 5         40.428552
# ..                                                 ...               ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         40.443750
# 260  Avenida de la Complutense (Metro Ciudad Univer...         40.443420
# 261          Calle José Antonio Novais frente al nº 12         40.448332
# 262                          Avenida Complutense nº 23         40.451090
# 263                                Calle Zurbano nº 90         40.438370
#
#      Longitude.bicimad
# 0            -3.701834
# 1            -3.701603
# 2            -3.705842
# 3            -3.706917
# 4            -3.702587
# ..                 ...
# 259          -3.726990
# 260          -3.726930
# 261          -3.727295
# 262          -3.729370
# 263          -3.692810
#
# [264 rows x 4 columns]

# %%
# %%time
df_bicimad_final['location_bicimad']= df_bicimad_final.apply(lambda x: to_mercator (x['Latitude.bicimad'], x['Longitude.bicimad']), axis=1)
# Out:
# /Users/Izaskun/miniconda3/envs/bicimad/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_bicimad_final
# Out:
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  Latitude.bicimad  \
# 0                                  Puerta del Sol nº 1         40.417214
# 1                                  Puerta del Sol nº 1         40.417313
# 2                               Calle Miguel Moya nº 1         40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4                          Calle Manuela Malasaña nº 5         40.428552
# ..                                                 ...               ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         40.443750
# 260  Avenida de la Complutense (Metro Ciudad Univer...         40.443420
# 261          Calle José Antonio Novais frente al nº 12         40.448332
# 262                          Avenida Complutense nº 23         40.451090
# 263                                Calle Zurbano nº 90         40.438370
#
#      Longitude.bicimad                              location_bicimad
# 0            -3.701834  POINT (4499223.648366921 -412373.2851572837)
# 1            -3.701603   POINT (4499234.670122574 -412347.498528782)
# 2            -3.705842  POINT (4499599.340516399 -412820.3206106317)
# 3            -3.706917  POINT (4500679.707306497 -412940.3068148262)
# 4            -3.702587  POINT (4500485.866677178 -412457.3286497012)
# ..                 ...                                           ...
# 259          -3.726990  POINT (4502177.655770458 -415179.5220676512)
# 260          -3.726930  POINT (4502140.920338497 -415172.8287427756)
# 261          -3.727295  POINT (4502687.743941171 -415213.4906984274)
# 262          -3.729370    POINT (4502994.74083288 -415445.024322674)
# 263          -3.692810  POINT (4501578.756909991 -411366.6317244973)
#
# [264 rows x 5 columns]

# %%
#Centros Deportivos

# %%
url = 'https://datos.madrid.es/egob/catalogo/212808-0-espacio-deporte.json'
r= requests.get(url).json()
df = pd.json_normalize(r['@graph'])
df_centros_deportivos= df [['title', 'address.street-address', 'location.latitude', 'location.longitude'] ]
df_centros_deportivos
# Out:
#                                                  title  \
# 0            Campo de Golf del Centro Nacional de Golf
# 1    Campo de Golf del Club de Golf Olivar de la Hi...
# 2                  Campos de Fútbol Ernesto Cotorruelo
# 3    Centro Comercial Dreams - Palacio Municipal de...
# 4    Centro de Alto Rendimiento del Consejo Superio...
# ..                                                 ...
# 606                               Piscina SAGE Fitness
# 607                    Pista de Patinaje Paco de Lucía
# 608      Pista de petanca Centro de Mayores La Vaguada
# 609                    Polideportivo Antonio Magariños
# 610                                      WiZink Center
#
#                             address.street-address  location.latitude  \
# 0                         CALLE ARROYO DEL MONTE 5          40.485508
# 1                           CALLE VIA DE DUBLIN 12          40.465351
# 2                             CALLE VIA LUSITANA 5          40.381231
# 3                                 CALLE SILVANO 77          40.462913
# 4                            CALLE MARTIN FIERRO 5          40.436812
# ..                                             ...                ...
# 606                              CALLE ESCALONA 59          40.397182
# 607                       AUDITORIO PACO DE LUCIA           40.385278
# 608                   AVENIDA MONFORTE DE LEMOS 36          40.479033
# 609                              CALLE SERRANO 129          40.442522
# 610  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
#
#      location.longitude
# 0             -3.735279
# 1             -3.611293
# 2             -3.724179
# 3             -3.635734
# 4             -3.731957
# ..                  ...
# 606           -3.761105
# 607           -3.764155
# 608           -3.708264
# 609           -3.686096
# 610           -3.672104
#
# [611 rows x 4 columns]

# %%
df_centros_deportivos['location_centros']= df_centros_deportivos.apply(lambda x: to_mercator (x['location.latitude'], x['location.longitude']), axis=1)
# Out:
# /Users/Izaskun/miniconda3/envs/bicimad/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_centros_deportivos
# Out:
#                                                  title  \
# 0            Campo de Golf del Centro Nacional de Golf
# 1    Campo de Golf del Club de Golf Olivar de la Hi...
# 2                  Campos de Fútbol Ernesto Cotorruelo
# 3    Centro Comercial Dreams - Palacio Municipal de...
# 4    Centro de Alto Rendimiento del Consejo Superio...
# ..                                                 ...
# 606                               Piscina SAGE Fitness
# 607                    Pista de Patinaje Paco de Lucía
# 608      Pista de petanca Centro de Mayores La Vaguada
# 609                    Polideportivo Antonio Magariños
# 610                                      WiZink Center
#
#                             address.street-address  location.latitude  \
# 0                         CALLE ARROYO DEL MONTE 5          40.485508
# 1                           CALLE VIA DE DUBLIN 12          40.465351
# 2                             CALLE VIA LUSITANA 5          40.381231
# 3                                 CALLE SILVANO 77          40.462913
# 4                            CALLE MARTIN FIERRO 5          40.436812
# ..                                             ...                ...
# 606                              CALLE ESCALONA 59          40.397182
# 607                       AUDITORIO PACO DE LUCIA           40.385278
# 608                   AVENIDA MONFORTE DE LEMOS 36          40.479033
# 609                              CALLE SERRANO 129          40.442522
# 610  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
#
#      location.longitude                              location_centros
# 0             -3.735279  POINT (4506826.154319164 -416104.2065551275)
# 1             -3.611293  POINT (4504582.255355831 -402273.7208142197)
# 2             -3.724179   POINT (4495218.036163405 -414865.966552915)
# 3             -3.635734  POINT (4504310.842371287 -404999.9123872458)
# 4             -3.731957  POINT (4501405.320516344 -415733.6645299961)
# ..                  ...                                           ...
# 606           -3.761105  POINT (4496993.758844213 -418985.2758262118)
# 607           -3.764155  POINT (4495668.617279258 -419325.5917997775)
# 608           -3.708264  POINT (4506105.338268181 -413090.5785481936)
# 609           -3.686096  POINT (4502040.979548661 -410617.7057179091)
# 610           -3.672104  POINT (4499899.340417478 -409056.8845014666)
#
# [611 rows x 5 columns]

# %%
#Input

# %%
#centro = input("Enter a centro: ")
#centro_ejemplo= "Campo de Golf del Centro Nacional de Golf"

# %%
# Distance function

# %%
def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
def distance_meters(location_centros, location_bicimad):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    return location_centros.distance(location_bicimad)

# %%
#def row_filter (df, cat_var, cat_values, sort_by):
#    df = df[ df [cat_var] .isin(cat_values) ].sort_values(by=sort_by, ascending=False)
# mask = df1['player_country'].isin(['Spain'])

# %%
cat_values= ["Campo de Golf del Centro Nacional de Golf"]

# %%
#tt= df_centros_deportivos[df_centros_deportivos['location.latitude'].isin([cat_values])]
t= df_centros_deportivos[df_centros_deportivos['title'].isin(cat_values)][['location.latitude','location.longitude']]

# %%
t
# Out:
#    location.latitude  location.longitude
# 0          40.485508           -3.735279

# %%
t.values
# Out:
# array([[40.48550817, -3.73527898]])

# %%
lista= t.values.tolist()[0]

# %%
lista
# Out:
# [40.4855081729451, -3.735278975476509]

# %%
lista[1]
# Out:
# -3.735278975476509

# %%
def name_to_coordinates(name):
    t= df_centros_deportivos[df_centros_deportivos['title'].isin([name])][['location.latitude','location.longitude']]
    lista= t.values.tolist()[0]
    lat= lista[0]
    lon= lista[1]
    return lat, lon

# %%
name_to_coordinates ("Campo de Golf del Centro Nacional de Golf")
# Out:
# (40.4855081729451, -3.735278975476509)

# %%
#Mergeo los dos dataframes

# %%
df_merged = df_centros_deportivos.assign(key=0).merge(df_bicimad_final.assign(key=0),
                                                      how='left',
                                                      on = 'key')

# %%
df_merged
# Out:
#                                             title  \
# 0       Campo de Golf del Centro Nacional de Golf
# 1       Campo de Golf del Centro Nacional de Golf
# 2       Campo de Golf del Centro Nacional de Golf
# 3       Campo de Golf del Centro Nacional de Golf
# 4       Campo de Golf del Centro Nacional de Golf
# ...                                           ...
# 161299                              WiZink Center
# 161300                              WiZink Center
# 161301                              WiZink Center
# 161302                              WiZink Center
# 161303                              WiZink Center
#
#                                address.street-address  location.latitude  \
# 0                            CALLE ARROYO DEL MONTE 5          40.485508
# 1                            CALLE ARROYO DEL MONTE 5          40.485508
# 2                            CALLE ARROYO DEL MONTE 5          40.485508
# 3                            CALLE ARROYO DEL MONTE 5          40.485508
# 4                            CALLE ARROYO DEL MONTE 5          40.485508
# ...                                               ...                ...
# 161299  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
# 161300  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
# 161301  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
# 161302  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
# 161303  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
#
#         location.longitude                              location_centros  key  \
# 0                -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# 1                -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# 2                -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# 3                -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# 4                -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# ...                    ...                                           ...  ...
# 161299           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
# 161300           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
# 161301           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
# 161302           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
# 161303           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
#
#                           name  \
# 0             Puerta del Sol A
# 1             Puerta del Sol B
# 2                  Miguel Moya
# 3           Plaza Conde Suchil
# 4                     Malasaña
# ...                        ...
# 161299  Ciudad Universitaria 1
# 161300  Ciudad Universitaria 2
# 161301       Facultad Biología
# 161302        Facultad Derecho
# 161303                 Zurbano
#
#                                                   address  Latitude.bicimad  \
# 0                                     Puerta del Sol nº 1         40.417214
# 1                                     Puerta del Sol nº 1         40.417313
# 2                                  Calle Miguel Moya nº 1         40.420589
# 3                Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4                             Calle Manuela Malasaña nº 5         40.428552
# ...                                                   ...               ...
# 161299  Avenida de la Complutense (Metro Ciudad Univer...         40.443750
# 161300  Avenida de la Complutense (Metro Ciudad Univer...         40.443420
# 161301          Calle José Antonio Novais frente al nº 12         40.448332
# 161302                          Avenida Complutense nº 23         40.451090
# 161303                                Calle Zurbano nº 90         40.438370
#
#         Longitude.bicimad                              location_bicimad  \
# 0               -3.701834  POINT (4499223.648366921 -412373.2851572837)
# 1               -3.701603   POINT (4499234.670122574 -412347.498528782)
# 2               -3.705842  POINT (4499599.340516399 -412820.3206106317)
# 3               -3.706917  POINT (4500679.707306497 -412940.3068148262)
# 4               -3.702587  POINT (4500485.866677178 -412457.3286497012)
# ...                   ...                                           ...
# 161299          -3.726990  POINT (4502177.655770458 -415179.5220676512)
# 161300          -3.726930  POINT (4502140.920338497 -415172.8287427756)
# 161301          -3.727295  POINT (4502687.743941171 -415213.4906984274)
# 161302          -3.729370    POINT (4502994.74083288 -415445.024322674)
# 161303          -3.692810  POINT (4501578.756909991 -411366.6317244973)
#
#            Distance
# 0       8468.640459
# 1       8470.152744
# 2       7937.930753
# 3       6912.964085
# 4       7314.298725
# ...             ...
# 161299  6532.795084
# 161300  6513.789566
# 161301  6758.623682
# 161302  7098.579725
# 161303  2855.761193
#
# [161304 rows x 12 columns]

# %%
#df_bicimad['Longitude.bicimad'] = 
#df_bicimad.apply(lambda x: lat(x['geometry_coordinates']),axis=1)
df_merged['Distance']= df_merged.apply(lambda x: distance_meters (x ['location_bicimad'],
                                                                  x ['location_centros']),
                                       axis=1 )

# %%
df_merged.head()
# Out:
#                                        title    address.street-address  \
# 0  Campo de Golf del Centro Nacional de Golf  CALLE ARROYO DEL MONTE 5
# 1  Campo de Golf del Centro Nacional de Golf  CALLE ARROYO DEL MONTE 5
# 2  Campo de Golf del Centro Nacional de Golf  CALLE ARROYO DEL MONTE 5
# 3  Campo de Golf del Centro Nacional de Golf  CALLE ARROYO DEL MONTE 5
# 4  Campo de Golf del Centro Nacional de Golf  CALLE ARROYO DEL MONTE 5
#
#    location.latitude  location.longitude  \
# 0          40.485508           -3.735279
# 1          40.485508           -3.735279
# 2          40.485508           -3.735279
# 3          40.485508           -3.735279
# 4          40.485508           -3.735279
#
#                                location_centros  key                name  \
# 0  POINT (4506826.154319164 -416104.2065551275)    0    Puerta del Sol A
# 1  POINT (4506826.154319164 -416104.2065551275)    0    Puerta del Sol B
# 2  POINT (4506826.154319164 -416104.2065551275)    0         Miguel Moya
# 3  POINT (4506826.154319164 -416104.2065551275)    0  Plaza Conde Suchil
# 4  POINT (4506826.154319164 -416104.2065551275)    0            Malasaña
#
#                                     address  Latitude.bicimad  \
# 0                       Puerta del Sol nº 1         40.417214
# 1                       Puerta del Sol nº 1         40.417313
# 2                    Calle Miguel Moya nº 1         40.420589
# 3  Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4               Calle Manuela Malasaña nº 5         40.428552
#
#    Longitude.bicimad                              location_bicimad  \
# 0          -3.701834  POINT (4499223.648366921 -412373.2851572837)
# 1          -3.701603   POINT (4499234.670122574 -412347.498528782)
# 2          -3.705842  POINT (4499599.340516399 -412820.3206106317)
# 3          -3.706917  POINT (4500679.707306497 -412940.3068148262)
# 4          -3.702587  POINT (4500485.866677178 -412457.3286497012)
#
#       Distance
# 0  8468.640459
# 1  8470.152744
# 2  7937.930753
# 3  6912.964085
# 4  7314.298725

# %%
min_distances= df_merged.groupby('title')['Distance'].min().reset_index()

min_distances
# Out:
#                                                  title     Distance
# 0            Campo de Golf del Centro Nacional de Golf  3887.705045
# 1    Campo de Golf del Club de Golf Olivar de la Hi...  4843.269670
# 2                  Campos de Fútbol Ernesto Cotorruelo  2074.787928
# 3    Centro Comercial Dreams - Palacio Municipal de...  2597.642883
# 4    Centro Deportivo Municipal  María Jesús Rosa (...  2162.785163
# ..                                                 ...          ...
# 606                               Piscina SAGE Fitness  3869.554385
# 607                    Pista de Patinaje Paco de Lucía  4779.660155
# 608      Pista de petanca Centro de Mayores La Vaguada  2159.005542
# 609                    Polideportivo Antonio Magariños   162.774690
# 610                                      WiZink Center   223.496235
#
# [611 rows x 2 columns]

# %%
df_pretty = min_distances.merge(df_merged, how='left', on = ['Distance', 'title'])

# %%
df_m = pd.merge(min_distances, 
                df_merged,
                how='left', 
                left_on=['Distance','title'], 
                right_on = ['Distance','title'])
df_m
# Out:
#                                                  title     Distance  \
# 0            Campo de Golf del Centro Nacional de Golf  3887.705045
# 1    Campo de Golf del Club de Golf Olivar de la Hi...  4843.269670
# 2                  Campos de Fútbol Ernesto Cotorruelo  2074.787928
# 3    Centro Comercial Dreams - Palacio Municipal de...  2597.642883
# 4    Centro Deportivo Municipal  María Jesús Rosa (...  2162.785163
# ..                                                 ...          ...
# 869                               Piscina SAGE Fitness  3869.554385
# 870                    Pista de Patinaje Paco de Lucía  4779.660155
# 871      Pista de petanca Centro de Mayores La Vaguada  2159.005542
# 872                    Polideportivo Antonio Magariños   162.774690
# 873                                      WiZink Center   223.496235
#
#                             address.street-address  location.latitude  \
# 0                         CALLE ARROYO DEL MONTE 5          40.485508
# 1                           CALLE VIA DE DUBLIN 12          40.465351
# 2                             CALLE VIA LUSITANA 5          40.381231
# 3                                 CALLE SILVANO 77          40.462913
# 4                     AVENIDA MONFORTE DE LEMOS 38          40.478768
# ..                                             ...                ...
# 869                              CALLE ESCALONA 59          40.397182
# 870                       AUDITORIO PACO DE LUCIA           40.385278
# 871                   AVENIDA MONFORTE DE LEMOS 36          40.479033
# 872                              CALLE SERRANO 129          40.442522
# 873  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
#
#      location.longitude                              location_centros  key  \
# 0             -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# 1             -3.611293  POINT (4504582.255355831 -402273.7208142197)    0
# 2             -3.724179   POINT (4495218.036163405 -414865.966552915)    0
# 3             -3.635734  POINT (4504310.842371287 -404999.9123872458)    0
# 4             -3.708699  POINT (4506075.795342792 -413139.1196950942)    0
# ..                  ...                                           ...  ...
# 869           -3.761105  POINT (4496993.758844213 -418985.2758262118)    0
# 870           -3.764155  POINT (4495668.617279258 -419325.5917997775)    0
# 871           -3.708264  POINT (4506105.338268181 -413090.5785481936)    0
# 872           -3.686096  POINT (4502040.979548661 -410617.7057179091)    0
# 873           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
#
#                    name                           address  Latitude.bicimad  \
# 0      Facultad Derecho         Avenida Complutense nº 23         40.451090
# 1       Carlota O’Neill       Calle Carlota O'Neill nº 32         40.443705
# 2    Marqués de Vadillo  Glorieta Marqués de Vadillo nº 9         40.398247
# 3       Carlota O’Neill       Calle Carlota O'Neill nº 32         40.443705
# 4               Remonta               Calle Azucenas nº 1         40.463028
# ..                  ...                               ...               ...
# 869            Caramuel              Calle Caramuel nº 51         40.409136
# 870            Caramuel              Calle Caramuel nº 51         40.409136
# 871             Remonta               Calle Azucenas nº 1         40.463028
# 872         Serrano 113             Calle Serrano nº 113B         40.441060
# 873           O'Donnell             Calle O'Donnell nº 50         40.421315
#
#      Longitude.bicimad                              location_bicimad
# 0            -3.729370    POINT (4502994.74083288 -415445.024322674)
# 1            -3.648958  POINT (4502172.693570442 -406475.0626355441)
# 2            -3.716591  POINT (4497112.284980891 -414019.4641230708)
# 3            -3.648958  POINT (4502172.693570442 -406475.0626355441)
# 4            -3.697333  POINT (4504323.639518123 -411871.2121165185)
# ..                 ...                                           ...
# 869          -3.728534  POINT (4498324.476616229 -415351.7319152079)
# 870          -3.728534  POINT (4498324.476616229 -415351.7319152079)
# 871          -3.697333  POINT (4504323.639518123 -411871.2121165185)
# 872          -3.686090  POINT (4501878.206340224 -410617.0111451639)
# 873          -3.672497  POINT (4499680.180730613 -409100.6977278018)
#
# [874 rows x 12 columns]

# %%
df_pretty
# Out:
#                                                  title     Distance  \
# 0            Campo de Golf del Centro Nacional de Golf  3887.705045
# 1    Campo de Golf del Club de Golf Olivar de la Hi...  4843.269670
# 2                  Campos de Fútbol Ernesto Cotorruelo  2074.787928
# 3    Centro Comercial Dreams - Palacio Municipal de...  2597.642883
# 4    Centro Deportivo Municipal  María Jesús Rosa (...  2162.785163
# ..                                                 ...          ...
# 869                               Piscina SAGE Fitness  3869.554385
# 870                    Pista de Patinaje Paco de Lucía  4779.660155
# 871      Pista de petanca Centro de Mayores La Vaguada  2159.005542
# 872                    Polideportivo Antonio Magariños   162.774690
# 873                                      WiZink Center   223.496235
#
#                             address.street-address  location.latitude  \
# 0                         CALLE ARROYO DEL MONTE 5          40.485508
# 1                           CALLE VIA DE DUBLIN 12          40.465351
# 2                             CALLE VIA LUSITANA 5          40.381231
# 3                                 CALLE SILVANO 77          40.462913
# 4                     AVENIDA MONFORTE DE LEMOS 38          40.478768
# ..                                             ...                ...
# 869                              CALLE ESCALONA 59          40.397182
# 870                       AUDITORIO PACO DE LUCIA           40.385278
# 871                   AVENIDA MONFORTE DE LEMOS 36          40.479033
# 872                              CALLE SERRANO 129          40.442522
# 873  CALLE JORGE JUAN 99 Avenida de Felipe II, s/n          40.423284
#
#      location.longitude                              location_centros  key  \
# 0             -3.735279  POINT (4506826.154319164 -416104.2065551275)    0
# 1             -3.611293  POINT (4504582.255355831 -402273.7208142197)    0
# 2             -3.724179   POINT (4495218.036163405 -414865.966552915)    0
# 3             -3.635734  POINT (4504310.842371287 -404999.9123872458)    0
# 4             -3.708699  POINT (4506075.795342792 -413139.1196950942)    0
# ..                  ...                                           ...  ...
# 869           -3.761105  POINT (4496993.758844213 -418985.2758262118)    0
# 870           -3.764155  POINT (4495668.617279258 -419325.5917997775)    0
# 871           -3.708264  POINT (4506105.338268181 -413090.5785481936)    0
# 872           -3.686096  POINT (4502040.979548661 -410617.7057179091)    0
# 873           -3.672104  POINT (4499899.340417478 -409056.8845014666)    0
#
#                    name                           address  Latitude.bicimad  \
# 0      Facultad Derecho         Avenida Complutense nº 23         40.451090
# 1       Carlota O’Neill       Calle Carlota O'Neill nº 32         40.443705
# 2    Marqués de Vadillo  Glorieta Marqués de Vadillo nº 9         40.398247
# 3       Carlota O’Neill       Calle Carlota O'Neill nº 32         40.443705
# 4               Remonta               Calle Azucenas nº 1         40.463028
# ..                  ...                               ...               ...
# 869            Caramuel              Calle Caramuel nº 51         40.409136
# 870            Caramuel              Calle Caramuel nº 51         40.409136
# 871             Remonta               Calle Azucenas nº 1         40.463028
# 872         Serrano 113             Calle Serrano nº 113B         40.441060
# 873           O'Donnell             Calle O'Donnell nº 50         40.421315
#
#      Longitude.bicimad                              location_bicimad
# 0            -3.729370    POINT (4502994.74083288 -415445.024322674)
# 1            -3.648958  POINT (4502172.693570442 -406475.0626355441)
# 2            -3.716591  POINT (4497112.284980891 -414019.4641230708)
# 3            -3.648958  POINT (4502172.693570442 -406475.0626355441)
# 4            -3.697333  POINT (4504323.639518123 -411871.2121165185)
# ..                 ...                                           ...
# 869          -3.728534  POINT (4498324.476616229 -415351.7319152079)
# 870          -3.728534  POINT (4498324.476616229 -415351.7319152079)
# 871          -3.697333  POINT (4504323.639518123 -411871.2121165185)
# 872          -3.686090  POINT (4501878.206340224 -410617.0111451639)
# 873          -3.672497  POINT (4499680.180730613 -409100.6977278018)
#
# [874 rows x 12 columns]

# %%
df_pretty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 874 entries, 0 to 873
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   874 non-null    object
#  1   Distance                874 non-null    float64
#  2   address.street-address  874 non-null    object
#  3   location.latitude       610 non-null    float64
#  4   location.longitude      610 non-null    float64
#  5   location_centros        874 non-null    object
#  6   key                     874 non-null    int64
#  7   name                    874 non-null    object
#  8   address                 874 non-null    object
#  9   Latitude.bicimad        874 non-null    float64
#  10  Longitude.bicimad       874 non-null    float64
#  11  location_bicimad        874 non-null    object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 88.8+ KB
