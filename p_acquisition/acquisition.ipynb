# %%
# Import libraries
import pandas as pd
import requests
import re

# %%
url = 'https://datos.madrid.es/egob/catalogo/212808-0-espacio-deporte.json'

# %%
#mi response al aplicar .json() ya es un diccionario
response= requests.get(url).json()
type (response)
# Out:
# dict

# %%
r.keys()
# Out:
# dict_keys(['@context', '@graph'])

# %%
df = pd.json_normalize(r['@graph'])
df
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4    https://datos.madrid.es/egob/catalogo/tipo/ent...
# ..                                                 ...
# 606  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 607  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 608  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 609  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 610  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                  @type        id  \
# 0    https://datos.madrid.es/egob/kos/entidadesYorg...    181447
# 1    https://datos.madrid.es/egob/kos/entidadesYorg...      4670
# 2    https://datos.madrid.es/egob/kos/entidadesYorg...     56494
# ...

# %%
#Titles /Place of interest column
titles = df['title']
titles
# Out:
# 0              Campo de Golf del Centro Nacional de Golf
# 1      Campo de Golf del Club de Golf Olivar de la Hi...
# 2                    Campos de Fútbol Ernesto Cotorruelo
# 3      Centro Comercial Dreams - Palacio Municipal de...
# 4      Centro de Alto Rendimiento del Consejo Superio...
#                              ...
# 606                                 Piscina SAGE Fitness
# 607                      Pista de Patinaje Paco de Lucía
# 608        Pista de petanca Centro de Mayores La Vaguada
# 609                      Polideportivo Antonio Magariños
# 610                                        WiZink Center
# Name: title, Length: 611, dtype: object

# %%
address = df ['address.street-address']
address
# Out:
# 0                           CALLE ARROYO DEL MONTE 5
# 1                             CALLE VIA DE DUBLIN 12
# 2                               CALLE VIA LUSITANA 5
# 3                                   CALLE SILVANO 77
# 4                              CALLE MARTIN FIERRO 5
#                            ...
# 606                                CALLE ESCALONA 59
# 607                         AUDITORIO PACO DE LUCIA
# 608                     AVENIDA MONFORTE DE LEMOS 36
# 609                                CALLE SERRANO 129
# 610    CALLE JORGE JUAN 99 Avenida de Felipe II, s/n
# Name: address.street-address, Length: 611, dtype: object

# %%
columns = ['Place of interest', 'Address', 'Latitude', 'Longitude'] 
df1= df [['title', 'address.street-address', 'location.latitude', 'location.longitude' ]]
df1
# Out:
#                                                  title  \
# 0            Campo de Golf del Centro Nacional de Golf
# 1    Campo de Golf del Club de Golf Olivar de la Hi...
# 2                  Campos de Fútbol Ernesto Cotorruelo
# 3    Centro Comercial Dreams - Palacio Municipal de...
# 4    Centro de Alto Rendimiento del Consejo Superio...
# ..                                                 ...
# 606                               Piscina SAGE Fitness
# 607                    Pista de Patinaje Paco de Lucía
# 608      Pista de petanca Centro de Mayores La Vaguada
# 609                    Polideportivo Antonio Magariños
# 610                                      WiZink Center
#
#                             address.street-address  location.latitude  \
# 0                         CALLE ARROYO DEL MONTE 5          40.485508
# 1                           CALLE VIA DE DUBLIN 12          40.465351
# 2                             CALLE VIA LUSITANA 5          40.381231
# ...
